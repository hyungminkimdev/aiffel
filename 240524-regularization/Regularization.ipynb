# %% [markdown]
# # 7. Regularization
#
# ## 7-1. 들어가며
#
# ### 학습 목표
# ---
# - 정칙화(Regularization)의 개념을 이해하고 정규화(Normalization)와 구분합니다.
# - L1 regularization과 L2 regularization의 차이를 설명합니다.
# - 실습을 통하여 Lp norm, Dropout, Batch Normalization에 대해 학습합니다.
#
# ### 목차
# ---
# 1. 들어가며
# 2. Regularization과 Normalization
# 3. L1 Regularization
# 4. L2 Regularization
# 5. Extra : Lp norm
# 6. Dropout
# 7. Batch Normalization
#
# ## 7-2. Regularization과 Normalization
#
# ### Regularization(정칙화)
# ---
# 정칙화라고 불리며, 오버피팅(overfitting)을 해결하기 위한 방법 중의 하나입니다. 오늘 우리가 가장 중요하게 다룰 주제이기도 하지요. L1, L2 Regularization, Dropout, Batch normalization 등이 있습니다. 오버피팅은 한국어로 과적합이라고 하며, train set은 매우 잘 맞히지만, validation/test set은 맞히지 못하는 현상을 말합니다. 비유하자면 오버피팅은 기출문제는 외워서 잘 맞히지만 새로운 응용 문제로 시험을 볼 때는 잘 풀지 못하는 경우라고 할 수 있겠습니다. 더 좋은 결과를 얻기 위해서는 새로운 시험, 즉 test set에서도 잘 맞혀야겠죠? 그래서 regularization 기법들은 모델에 제약 조건을 걸어서 모델의 train loss를 증가시키는 역할을 합니다. 그래서 train loss는 약간 증가하지만 결과적으로, validation loss나 최종 test loss를 감소시키려는 목적을 가지고 있지요.
#
# ### Normalization(정규화)
# ---
# 정규화라고 불리며, 이는 데이터의 형태를 좀 더 의미 있게, 혹은 트레이닝에 적합하게 전처리하는 과정입니다. 데이터를 z-score로 바꾸거나 minmax scaler를 사용하여 0과 1사이의 값으로 분포를 조정하는 것들이 해당됩니다. 예를 들어, 금액과 같은 큰 범위의 값(10,000 ~ 10,000,000)과 시간(0~24)의 값이 들어가는 경우, 데이터의 분포가 피처(feature) 값의 범위에 의해 왜곡되어 학습에 방해가 된다는 문제가 있습니다. normalization은 모든 피처 값의 범위를 동일하게 하여 모델이 풀어야 하는 문제를 좀 더 간단하게 바꾸어 주는 전처리 과정입니다.
#
# 이 두 가지 단어는 한국어로 번역 시에 혼용하여 쓰기도 하므로, 앞으로 이번 노드에서는 주로 영어로 표기하도록 하겠습니다. 핵심을 정리하면, regularization은 오버피팅을 막고자 하는 방법, normalization은 트레이닝을 할 때에 서로 범위가 다른 데이터들을 같은 범위로 바꿔주는 전처리 과정이라는 것입니다.
#
# Regularization와 Normalization의 간단한 예제를 Iris dataset의 회귀 문제를 풀면서 비교해 보겠습니다.

# %%
from sklearn.datasets import load_iris
import pandas as pd 
import matplotlib.pyplot as plt

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
target_df = pd.DataFrame(data=iris.target, columns=['species'])

# 0, 1, 2로 되어있는 target 데이터를 
# 알아보기 쉽게 'setosa', 'versicolor', 'virginica'로 바꿉니다 
def converter(species):
    if species == 0:
        return 'setosa'
    elif species == 1:
        return 'versicolor'
    else:
        return 'virginica'

target_df['species'] = target_df['species'].apply(converter)

iris_df = pd.concat([iris_df, target_df], axis=1)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
X = [iris_df['petal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']
Y = [iris_df['sepal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']

print("petal length(꽃잎 길이)", X)
print("sepal length(꽃받침의 길이)", Y)
# Out:
# petal length(꽃잎 길이) [6.0, 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5.0, 5.1, 5.3, 5.5, 6.7, 6.9, 5.0, 5.7, 4.9, 6.7, 4.9, 5.7, 6.0, 4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5.0, 5.2, 5.4, 5.1]
# sepal length(꽃받침의 길이) [6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]

# %%
plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.title('petal-sepal scatter before normalization') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %%
# minmax_scale을 통해 0-1로 normalization


from sklearn.preprocessing import minmax_scale

X_scale = minmax_scale(X)
Y_scale = minmax_scale(Y)

plt.figure(figsize=(5,5))
plt.scatter(X_scale,Y_scale)
plt.title('petal-sepal scatter after normalization') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %% [markdown]
# 이번엔 같은 데이터로 간단한 회귀 문제를 풀면서 regularization에 대해 알아보겠습니다.
#
# sklearn.linear_model에 포함된 LinearRegression 모델을 사용하여 X-Y 관계를 선형으로 모델링해 보겠습니다. 이 sklearn.linear_model에는 L1, L2 regression인 Lasso와 Ridge 모델도 함께 포함되어 있으므로, 이들의 차이점을 먼저 직관적으로 이해해 보겠습니다. 수학적 정의나 보다 구체적인 설명은 다음 스텝에 이어집니다.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np 

X = np.array(X)
Y = np.array(Y)

# Iris Dataset을 Linear Regression으로 학습합니다. 
linear= LinearRegression()
linear.fit(X.reshape(-1,1), Y)

# Linear Regression의 기울기와 절편을 확인합니다. 
a, b=linear.coef_, linear.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))
# Out:
# 기울기 : 1.00, 절편 : 1.06

# %%
plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.plot(X,linear.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with linear regression') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %%
# Q. linear regression의 코드를 참고하여, 아래 코드를 채워주세요!

# L1 regularization은 Lasso로 import 합니다.
from sklearn.linear_model import Lasso

L1 = Lasso()
L1.fit(X.reshape(-1,1), Y)
a, b = L1.coef_, L1.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
plt.scatter(X, Y)
plt.plot(X, linear.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with L1 regularization(Lasso)') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.00, 절편 : 6.59

# %%
# Q. linear regression의 코드를 참고하여, 아래 코드를 채워주세요!

# L2 regularization은 Ridge로 import 합니다.
from sklearn.linear_model import Ridge

L2 = Ridge()
L2.fit(X.reshape(-1,1), Y)
a, b = L2.coef_, L2.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
plt.scatter(X, Y)
plt.plot(X, linear.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with L2 regularization(Ridge)') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.93, 절편 : 1.41

# %% [markdown]
# ## 7-3. L1 Regularization
#
# 이전 스텝에서 regularization과 normalization의 정의를 설명하고, L1/L2 regularization을 코드로 맛보기 해보았습니다. 마지막에 같은 linear regression 문제를 푸는데 L1 regularization에서는 문제가 풀리지 않았다는 것을 기억하시나요?
#
# L1 regularization을 설명하면서, 지난 스텝에서 Lasso로는 regression 문제가 제대로 풀리지 않았던 현상을 더 자세히 알아보겠습니다. 그리고 어떤 때에 L1 regularization을 사용하는지 알아보는 것이 목표입니다!
#
# ### L1 regularization (Lasso)의 정의
# ---
# L1 regularization은 아래와 같은 식으로 정의됩니다. (N: 데이터의 개수, D: 데이터의 차원(feature의 개수))
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# 이 부분이 없다면 linear regression과 동일합니다.
#
# 이 부분이 바로 L1 norm에 해당하는 부분인데, L1 regularization이라는 이름이 붙은 이유이기도 하고, L2 regularization과의 차이가 나타나는 중요한 부분입니다.
#
# ![image-3.png](attachment:image-3.png)

# %%
from sklearn.datasets import load_iris
import pandas as pd 
import matplotlib.pyplot as plt

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
target_df = pd.DataFrame(data=iris.target, columns=['species'])

def converter(species):
    if species == 0:
        return 'setosa'
    elif species == 1:
        return 'versicolor'
    else:
        return 'virginica'

target_df['species'] = target_df['species'].apply(converter)

iris_df = pd.concat([iris_df, target_df], axis=1)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
X = [iris_df['petal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']
Y = [iris_df['sepal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']

X = np.array(X)
Y = np.array(Y)

plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %%
from sklearn.linear_model import Lasso

L1 = Lasso()
L1.fit(X.reshape(-1,1), Y)
a, b = L1.coef_, L1.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.plot(X,L1.predict(X.reshape(-1,1)),'-b')
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.00, 절편 : 6.59

# %% [markdown]
# ### 컬럼 수가 많은 데이터에서의 L1 regularization 비교
# ---
# Iris 데이터는 특성이 총 4개로 컬럼 수가 너무 적으니 wine dataset을 이용해 보겠습니다.
# 총 13개의 특성을 갖는 데이터입니다.

# %%
from sklearn.datasets import load_wine

wine = load_wine()
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
target_df = pd.DataFrame(data=wine.target, columns=['Y'])

# %%
wine_df.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
target_df.head(5)
# Out:
#    Y
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# 먼저 linear regression 으로 문제를 풀고, 그 계수(coefficient)와 절대 오차(mean absolute error), 제곱 오차(mean squared error), 평균 제곱값 오차(root mean squared error)를 출력해 보겠습니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 데이터를 준비하고
X_train, X_test, y_train, y_test = train_test_split(wine_df, target_df, test_size=0.3, random_state=101)

# 모델을 훈련시킵니다.
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트를 해볼까요?
pred = model.predict(X_test)

# 테스트 결과는 이렇습니다!
print("result of linear regression")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient linear regression")
print(model.coef_)
# Out:
# result of linear regression
# Mean Absolute Error: 0.25128973939722626
# Mean Squared Error: 0.1062458740952556
# Mean Root Squared Error: 0.32595379134971814
#
#
#  coefficient linear regression
# [[-8.09017190e-02  4.34817880e-02 -1.18857931e-01  3.65705449e-02
#   -4.68014203e-04  1.41423581e-01 -4.54107854e-01 -5.13172664e-01
#    9.69318443e-02  5.34311136e-02 -1.27626604e-01 -2.91381844e-01
#   -5.72238959e-04]]

# %% [markdown]
# 이번에는 L1 regularization으로 문제를 풀어보겠습니다.

# %%
# Q. 위의 Iris 예제 코드를 참고해서, 빈칸을 채워봅시다.

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 모델을 준비하고 훈련시킵니다.
L1 = Lasso(alpha=0.05)
L1.fit(X_train, y_train)

# 테스트를 해봅시다.
pred = L1.predict(X_test)

# 모델 성능은 얼마나 좋을까요?
print("Result of Lasso")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient of Lasso")
print(L1.coef_)
# Out:
# Result of Lasso
# Mean Absolute Error: 0.24233731936122138
# Mean Squared Error: 0.0955956894578189
# Mean Root Squared Error: 0.3091855259513597
#
#
#  coefficient of Lasso
# [-0.          0.01373795 -0.          0.03065716  0.00154719 -0.
#  -0.34143614 -0.          0.          0.06755943 -0.         -0.14558153
#  -0.00089635]

# %% [markdown]
# ### 결과 분석
# ---
# coefficient 부분을 보시면 linear regression과 L1 regularization의 차이가 좀 더 두드러짐을 알 수 있습니다. linear regression에서는 모든 컬럼의 가중치가 0이 아닌 값을 가지고 있지만, L1 regularization에서는 총 13개 중 7개를 제외한 나머지의 값들이 모두 0임을 확인할 수 있습니다. error 부분에서는 큰 차이가 없었지만, 우리가 어떤 컬럼이 결과에 영향을 더 크게 미치는지 확실히 확인할 수 있습니다. 이러한 경우 다른 문제에서도 error의 차이가 크게 나지 않는다면, 차원 축소와 비슷한 개념으로 변수의 값을 7개만 남겨도 충분히 결과를 예측할 수 있습니다. 다만 linear regression과 L1, L2 regularization의 차이 중 하나는 하이퍼파라미터(수식에서는 λ)가 하나 더 들어간다는 것이고, 그 값에 따라 error에 영향을 미친다는 점입니다.

# %% [markdown]
# ## 7-4. L2 Regularization
#
# ### L2 Regularization(Ridge)의 정의
# ---
# ![image.png](attachment:image.png)
#
# ### L1/L2 Regularization의 차이점
# ---
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# - 정규화에 대해 자세히 알아보자 (https://modulabs.co.kr/blog/learn-about-regularization/)

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

wine = load_wine()
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
target_df = pd.DataFrame(data=wine.target, columns=['Y'])
X_train, X_test, y_train, y_test = train_test_split(wine_df, target_df, test_size= 0.3, random_state=101)
print('=3')
# Out:
# =3

# %%
from sklearn.linear_model import Lasso

L1 = Lasso(alpha=0.05, max_iter=5)
L1.fit(X_train, y_train)
pred = L1.predict(X_test)

print("result of Lasso")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient of Lasso")
print(L1.coef_)
# Out:
# result of Lasso
# Mean Absolute Error: 0.24845768841769436
# Mean Squared Error: 0.10262989110341268
# Mean Root Squared Error: 0.32035900346862844
#
#
#  coefficient of Lasso
# [-0.          0.         -0.          0.03295564  0.00109495  0.
#  -0.4027847   0.          0.          0.06023131 -0.         -0.12001119
#  -0.00078971]
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.924e+00, tolerance: 7.480e-03
#   model = cd_fast.enet_coordinate_descent(

# %%
# Q. L1 regularization 코드를 참고하여 아래 코드를 채워주세요.

from sklearn.linear_model import Ridge

L2 = Ridge(alpha=0.05, max_iter=5)
L2.fit(X_train, y_train)
pred = L2.predict(X_test)


print("result of Ridge")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient of Ridge")
print(L2.coef_)
# Out:
# result of Ridge
# Mean Absolute Error: 0.251146695993643
# Mean Squared Error: 0.10568076460795564
# Mean Root Squared Error: 0.3250857803841251
#
#
#  coefficient of Ridge
# [[-8.12456257e-02  4.35541496e-02 -1.21661565e-01  3.65979773e-02
#   -3.94014013e-04  1.39168707e-01 -4.50691113e-01 -4.87216747e-01
#    9.54111059e-02  5.37077039e-02 -1.28602933e-01 -2.89832790e-01
#   -5.73136185e-04]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7-5. Extra : Lp norm
#
# 이전 스텝에서 잠깐 소개해드린 Lp norm에 대해 자세히 설명하겠습니다.
# Norm이라는 용어는 벡터뿐만 아니라 함수, 행렬의 크기를 나타내는 개념으로, 딥러닝을 배우는 과정에서는 주로 벡터, 좀 더 어렵게는 행렬의 norm 정도만 알면 됩니다.
#
# ### Vector norm
# ---
# L1 / L2 regularization에서 배운 norm은 벡터에서 정의된 norm으로 아래와 같습니다.
# ![image.png](attachment:image.png)
# 아래 코드에서 p의 값과 x의 형태를 바꾸어가며 실험해 보세요.

# %%
# [Playground] x와 p를 바꾸어가며 norm 값이 어떻게 변하는지 실험해봅시다!
# --------------------------- #
x = np.array([1,10,1,1,1])
p = 5
# --------------------------- #

norm_x = np.linalg.norm(x, ord=p)
making_norm = (sum(x**p))**(1/p)
print("result of numpy package norm function : %0.5f "%norm_x) 
print("result of making norm : %0.5f "%making_norm)
# Out:
# result of numpy package norm function : 10.00008
# result of making norm : 10.00008

# %%
# [Playground] x와 p를 바꾸어가며 norm 값이 어떻게 변하는지 실험해봅시다!
# --------------------------- #
x = np.array([13,5,2,8,10])
p = 10
# --------------------------- #

norm_x = np.linalg.norm(x, ord=p)
making_norm = (sum(x**p))**(1/p)
print("result of numpy package norm function : %0.5f "%norm_x) 
print("result of making norm : %0.5f "%making_norm)
# Out:
# result of numpy package norm function : 13.10092
# result of making norm : 13.10092

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
norm_x = np.linalg.norm(x, ord=np.inf)
print("result of infinite norm : %0.5f "%norm_x)
# Out:
# result of infinite norm : 13.00000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[1,2,3], [1,2,3], [4,6,8]])

one_norm_A = np.linalg.norm(A, ord=1)
print("result one norm of A :", one_norm_A)

inf_norm_A = np.linalg.norm(A, ord=np.inf)
print("result inf norm of A :", inf_norm_A)
# Out:
# result one norm of A : 14.0
# result inf norm of A : 18.0

# %% [markdown]
# ## 7-6. Dropout
#
# 드롭아웃(Dropout) 기법은 2014년도에 나온 논문입니다.
#
# 논문 제목 : Dropout: A Simple Way to Prevent Neural Networks from Overfitting
# 논문 발표 시점 : 2014년
# 논문 링크 : 논문 주소 (https://jmlr.org/papers/v15/srivastava14a.html)
#
# 드롭아웃 기법이 나오기 전의 신경망은 fully connected architecture로 모든 뉴런들이 연결되어 있었습니다.
#
# 드롭아웃이란 확률적으로 랜덤하게 몇 가지의 뉴런만 선택하여 정보를 전달하는 과정입니다. 이름 그대로 몇 가지의 값들을 모든 뉴런에 전달하는 것이 아닌, 확률적으로 버리면서 전달하는 기법입니다. 드롭아웃은 오버피팅을 막는 regularization layer 중 하나입니다. 확률을 너무 높이면 (비활성화된 뉴런의 비중을 높이면) 모델 안에서 값들이 제대로 전달되지 않으므로 학습이 잘 되지 않고, 확률을 너무 낮추는 경우에는 fully connected layer와 같이 동작합니다. fully connected layer에서 오버피팅이 생기는 경우에 주로 dropout layer를 추가합니다.
#
# 코드는 간단합니다. 논문이 나온 지도 오래되었기 때문에, 여러 프레임워크에서 간단하게 구현할 수 있도록 되어있습니다.
#
# - Keras Dropout(https://keras.io/api/layers/regularization_layers/dropout/)

# %% [markdown]
# ### 실습 (not overfitting)
# ---
# fashion mnist(https://keras.io/api/datasets/fashion_mnist/)라는 데이터 셋을 불러와서 학습을 시키도록 하겠습니다. 이 데이터셋은 총 10개의 클래스로 구성되어 있고, 데이터가 간단한 편이기도 하여 5 epoch 정도만 학습시켜도 어느 정도 결과가 나옵니다. 드롭아웃 레이어를 중간에 추가하여 확률을 1에 가깝게 주면 어떻게 되는지 살펴보도록 하겠습니다.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

fashion_mnist = keras.datasets.fashion_mnist
print('=3')
# Out:
# =3

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# dropout 확률을 0.9로 주었을 때의 결과

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    # 여기에 dropout layer를 추가해보았습니다. 나머지 layer는 아래의 실습과 같습니다.
    keras.layers.Dropout(0.9),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.4512 - accuracy: 0.4312
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.2095 - accuracy: 0.5067
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.1657 - accuracy: 0.5232
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.1308 - accuracy: 0.5367
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.1003 - accuracy: 0.5540

# %%
# dropout 없을 때

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    # 이번에는 dropout layer가 없습니다. 
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4955 - accuracy: 0.8251
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3740 - accuracy: 0.8641
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3332 - accuracy: 0.8777
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3110 - accuracy: 0.8868
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2920 - accuracy: 0.8937

# %% [markdown]
# ### 실습 (overfitting)
# ---
# overfitting이 되는지 확인해 보려면 train set과 validation set의 loss function을 그려보는 것이 가장 첫 번째 시도입니다. 우리는 위의 데이터를 이제 train:valid=99:1의 비율로 나눈 뒤에 loss function의 값을 그려보고, overfitting이 생기는 fully connected layer를 만들어보도록 합시다. overfitting이 되게 하기 위해 의도적으로 train set을 99%로 늘리고 validation set을 줄였습니다.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.01, random_state=101)
X_train = X_train / 255.0
X_valid = X_valid / 255.0

# Dense layer만으로 만들어 낸 classification 모델입니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=200, batch_size=512, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 117/117 [==============================] - 2s 15ms/step - loss: 2.0411 - accuracy: 0.4991 - val_loss: 1.6264 - val_accuracy: 0.5983
# Epoch 2/200
# 117/117 [==============================] - 2s 14ms/step - loss: 1.3806 - accuracy: 0.6202 - val_loss: 1.1576 - val_accuracy: 0.6617
# Epoch 3/200
# 117/117 [==============================] - 2s 13ms/step - loss: 1.0574 - accuracy: 0.6832 - val_loss: 0.9373 - val_accuracy: 0.7283
# Epoch 4/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.8846 - accuracy: 0.7213 - val_loss: 0.8063 - val_accuracy: 0.7600
# Epoch 5/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.7819 - accuracy: 0.7376 - val_loss: 0.7300 - val_accuracy: 0.7717
# Epoch 6/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.7212 - accuracy: 0.7467 - val_loss: 0.6853 - val_accuracy: 0.7733
# Epoch 7/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.6797 - accuracy: 0.7585 - val_loss: 0.6470 - val_accuracy: 0.7783
# Epoch 8/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.6492 - accuracy: 0.7662 - val_loss: 0.6245 - val_accuracy: 0.7867
# Epoch 9/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.6238 - accuracy: 0.7754 - val_loss: 0.6041 - val_accuracy: 0.7983
# Epoch 10/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.6053 - accuracy: 0.7831 - val_loss: 0.5859 - val_accuracy: 0.8017
# Epoch 11/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5865 - accuracy: 0.7891 - val_loss: 0.5719 - val_accuracy: 0.7950
# Epoch 12/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5707 - accuracy: 0.7967 - val_loss: 0.5607 - val_accuracy: 0.7900
# Epoch 13/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5573 - accuracy: 0.8021 - val_loss: 0.5479 - val_accuracy: 0.7983
# Epoch 14/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5455 - accuracy: 0.8076 - val_loss: 0.5361 - val_accuracy: 0.8033
# Epoch 15/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.5343 - accuracy: 0.8116 - val_loss: 0.5328 - val_accuracy: 0.8000
# Epoch 16/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5236 - accuracy: 0.8160 - val_loss: 0.5201 - val_accuracy: 0.8100
# Epoch 17/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5145 - accuracy: 0.8193 - val_loss: 0.5124 - val_accuracy: 0.8150
# Epoch 18/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.5067 - accuracy: 0.8225 - val_loss: 0.5053 - val_accuracy: 0.8133
# Epoch 19/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4993 - accuracy: 0.8253 - val_loss: 0.4972 - val_accuracy: 0.8167
# Epoch 20/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4928 - accuracy: 0.8269 - val_loss: 0.4914 - val_accuracy: 0.8200
# Epoch 21/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4868 - accuracy: 0.8288 - val_loss: 0.4975 - val_accuracy: 0.8150
# Epoch 22/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4822 - accuracy: 0.8303 - val_loss: 0.4804 - val_accuracy: 0.8217
# Epoch 23/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4764 - accuracy: 0.8333 - val_loss: 0.4779 - val_accuracy: 0.8250
# Epoch 24/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4709 - accuracy: 0.8344 - val_loss: 0.4739 - val_accuracy: 0.8283
# Epoch 25/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4662 - accuracy: 0.8368 - val_loss: 0.4704 - val_accuracy: 0.8300
# Epoch 26/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4624 - accuracy: 0.8384 - val_loss: 0.4673 - val_accuracy: 0.8300
# Epoch 27/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4595 - accuracy: 0.8387 - val_loss: 0.4625 - val_accuracy: 0.8283
# Epoch 28/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4555 - accuracy: 0.8398 - val_loss: 0.4633 - val_accuracy: 0.8317
# Epoch 29/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4540 - accuracy: 0.8406 - val_loss: 0.4574 - val_accuracy: 0.8333
# Epoch 30/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4491 - accuracy: 0.8425 - val_loss: 0.4589 - val_accuracy: 0.8317
# Epoch 31/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4462 - accuracy: 0.8440 - val_loss: 0.4511 - val_accuracy: 0.8300
# Epoch 32/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4430 - accuracy: 0.8451 - val_loss: 0.4497 - val_accuracy: 0.8283
# Epoch 33/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4406 - accuracy: 0.8459 - val_loss: 0.4501 - val_accuracy: 0.8300
# Epoch 34/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4387 - accuracy: 0.8460 - val_loss: 0.4450 - val_accuracy: 0.8333
# Epoch 35/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4362 - accuracy: 0.8460 - val_loss: 0.4427 - val_accuracy: 0.8383
# Epoch 36/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4329 - accuracy: 0.8484 - val_loss: 0.4394 - val_accuracy: 0.8333
# Epoch 37/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4310 - accuracy: 0.8490 - val_loss: 0.4417 - val_accuracy: 0.8317
# Epoch 38/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4290 - accuracy: 0.8496 - val_loss: 0.4355 - val_accuracy: 0.8383
# Epoch 39/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4258 - accuracy: 0.8510 - val_loss: 0.4318 - val_accuracy: 0.8367
# Epoch 40/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4246 - accuracy: 0.8507 - val_loss: 0.4342 - val_accuracy: 0.8367
# Epoch 41/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4221 - accuracy: 0.8518 - val_loss: 0.4329 - val_accuracy: 0.8383
# Epoch 42/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4201 - accuracy: 0.8529 - val_loss: 0.4268 - val_accuracy: 0.8333
# Epoch 43/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4182 - accuracy: 0.8530 - val_loss: 0.4303 - val_accuracy: 0.8350
# Epoch 44/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4172 - accuracy: 0.8540 - val_loss: 0.4247 - val_accuracy: 0.8383
# Epoch 45/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4143 - accuracy: 0.8548 - val_loss: 0.4243 - val_accuracy: 0.8333
# Epoch 46/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4128 - accuracy: 0.8549 - val_loss: 0.4229 - val_accuracy: 0.8400
# Epoch 47/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4116 - accuracy: 0.8555 - val_loss: 0.4184 - val_accuracy: 0.8317
# Epoch 48/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4097 - accuracy: 0.8567 - val_loss: 0.4179 - val_accuracy: 0.8350
# Epoch 49/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4074 - accuracy: 0.8571 - val_loss: 0.4155 - val_accuracy: 0.8350
# Epoch 50/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4064 - accuracy: 0.8572 - val_loss: 0.4168 - val_accuracy: 0.8333
# Epoch 51/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4046 - accuracy: 0.8581 - val_loss: 0.4152 - val_accuracy: 0.8317
# Epoch 52/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4039 - accuracy: 0.8583 - val_loss: 0.4113 - val_accuracy: 0.8400
# Epoch 53/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4015 - accuracy: 0.8590 - val_loss: 0.4104 - val_accuracy: 0.8367
# Epoch 54/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.4006 - accuracy: 0.8592 - val_loss: 0.4118 - val_accuracy: 0.8350
# Epoch 55/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3993 - accuracy: 0.8601 - val_loss: 0.4084 - val_accuracy: 0.8300
# Epoch 56/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3979 - accuracy: 0.8600 - val_loss: 0.4060 - val_accuracy: 0.8417
# Epoch 57/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3966 - accuracy: 0.8611 - val_loss: 0.4057 - val_accuracy: 0.8383
# Epoch 58/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3944 - accuracy: 0.8616 - val_loss: 0.4043 - val_accuracy: 0.8367
# Epoch 59/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3945 - accuracy: 0.8610 - val_loss: 0.4026 - val_accuracy: 0.8317
# Epoch 60/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3920 - accuracy: 0.8625 - val_loss: 0.4003 - val_accuracy: 0.8367
# Epoch 61/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.3917 - accuracy: 0.8620 - val_loss: 0.4032 - val_accuracy: 0.8417
# Epoch 62/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3904 - accuracy: 0.8625 - val_loss: 0.3989 - val_accuracy: 0.8383
# Epoch 63/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3884 - accuracy: 0.8634 - val_loss: 0.3973 - val_accuracy: 0.8433
# Epoch 64/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3872 - accuracy: 0.8635 - val_loss: 0.3961 - val_accuracy: 0.8367
# Epoch 65/200
# 117/117 [==============================] - 3s 25ms/step - loss: 0.3861 - accuracy: 0.8639 - val_loss: 0.3974 - val_accuracy: 0.8367
# Epoch 66/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3849 - accuracy: 0.8644 - val_loss: 0.3928 - val_accuracy: 0.8367
# Epoch 67/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3836 - accuracy: 0.8649 - val_loss: 0.3941 - val_accuracy: 0.8417
# Epoch 68/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3852 - accuracy: 0.8644 - val_loss: 0.3934 - val_accuracy: 0.8383
# Epoch 69/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3818 - accuracy: 0.8660 - val_loss: 0.3914 - val_accuracy: 0.8383
# Epoch 70/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3807 - accuracy: 0.8664 - val_loss: 0.3906 - val_accuracy: 0.8383
# Epoch 71/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3794 - accuracy: 0.8667 - val_loss: 0.3961 - val_accuracy: 0.8467
# Epoch 72/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3788 - accuracy: 0.8668 - val_loss: 0.3902 - val_accuracy: 0.8417
# Epoch 73/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3775 - accuracy: 0.8673 - val_loss: 0.3930 - val_accuracy: 0.8433
# Epoch 74/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3769 - accuracy: 0.8673 - val_loss: 0.3929 - val_accuracy: 0.8450
# Epoch 75/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3766 - accuracy: 0.8677 - val_loss: 0.3885 - val_accuracy: 0.8417
# Epoch 76/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3745 - accuracy: 0.8683 - val_loss: 0.3898 - val_accuracy: 0.8500
# Epoch 77/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3733 - accuracy: 0.8692 - val_loss: 0.3854 - val_accuracy: 0.8433
# Epoch 78/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3731 - accuracy: 0.8687 - val_loss: 0.3839 - val_accuracy: 0.8450
# Epoch 79/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3711 - accuracy: 0.8695 - val_loss: 0.3825 - val_accuracy: 0.8467
# Epoch 80/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.3710 - accuracy: 0.8697 - val_loss: 0.3823 - val_accuracy: 0.8433
# Epoch 81/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3691 - accuracy: 0.8707 - val_loss: 0.3833 - val_accuracy: 0.8367
# Epoch 82/200
# 117/117 [==============================] - 2s 13ms/step - loss: 0.3702 - accuracy: 0.8699 - val_loss: 0.3840 - val_accuracy: 0.8467
# Epoch 83/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.3687 - accuracy: 0.8702 - val_loss: 0.3805 - val_accuracy: 0.8417
# Epoch 84/200
# 117/117 [==============================] - 3s 24ms/step - loss: 0.3669 - accuracy: 0.8709 - val_loss: 0.3797 - val_accuracy: 0.8500
# Epoch 85/200
# 117/117 [==============================] - 3s 25ms/step - loss: 0.3656 - accuracy: 0.8707 - val_loss: 0.3798 - val_accuracy: 0.8517
# Epoch 86/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3660 - accuracy: 0.8711 - val_loss: 0.3786 - val_accuracy: 0.8483
# Epoch 87/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3640 - accuracy: 0.8723 - val_loss: 0.3861 - val_accuracy: 0.8533
# Epoch 88/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3646 - accuracy: 0.8715 - val_loss: 0.3767 - val_accuracy: 0.8400
# Epoch 89/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3633 - accuracy: 0.8720 - val_loss: 0.3766 - val_accuracy: 0.8500
# Epoch 90/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3612 - accuracy: 0.8735 - val_loss: 0.3780 - val_accuracy: 0.8567
# Epoch 91/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3605 - accuracy: 0.8732 - val_loss: 0.3720 - val_accuracy: 0.8517
# Epoch 92/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3600 - accuracy: 0.8727 - val_loss: 0.3753 - val_accuracy: 0.8483
# Epoch 93/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3594 - accuracy: 0.8735 - val_loss: 0.3727 - val_accuracy: 0.8483
# Epoch 94/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3577 - accuracy: 0.8744 - val_loss: 0.3747 - val_accuracy: 0.8500
# Epoch 95/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3573 - accuracy: 0.8742 - val_loss: 0.3738 - val_accuracy: 0.8550
# Epoch 96/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3558 - accuracy: 0.8749 - val_loss: 0.3686 - val_accuracy: 0.8517
# Epoch 97/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3553 - accuracy: 0.8749 - val_loss: 0.3700 - val_accuracy: 0.8567
# Epoch 98/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3545 - accuracy: 0.8751 - val_loss: 0.3713 - val_accuracy: 0.8467
# Epoch 99/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3539 - accuracy: 0.8758 - val_loss: 0.3713 - val_accuracy: 0.8517
# Epoch 100/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3565 - accuracy: 0.8747 - val_loss: 0.3747 - val_accuracy: 0.8467
# Epoch 101/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3522 - accuracy: 0.8760 - val_loss: 0.3677 - val_accuracy: 0.8467
# Epoch 102/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3519 - accuracy: 0.8758 - val_loss: 0.3696 - val_accuracy: 0.8517
# Epoch 103/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3507 - accuracy: 0.8767 - val_loss: 0.3669 - val_accuracy: 0.8450
# Epoch 104/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3494 - accuracy: 0.8762 - val_loss: 0.3628 - val_accuracy: 0.8500
# Epoch 105/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3492 - accuracy: 0.8774 - val_loss: 0.3653 - val_accuracy: 0.8517
# Epoch 106/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3484 - accuracy: 0.8773 - val_loss: 0.3647 - val_accuracy: 0.8517
# Epoch 107/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3489 - accuracy: 0.8767 - val_loss: 0.3677 - val_accuracy: 0.8500
# Epoch 108/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3466 - accuracy: 0.8777 - val_loss: 0.3659 - val_accuracy: 0.8517
# Epoch 109/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3464 - accuracy: 0.8782 - val_loss: 0.3661 - val_accuracy: 0.8533
# Epoch 110/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3468 - accuracy: 0.8774 - val_loss: 0.3687 - val_accuracy: 0.8567
# Epoch 111/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3443 - accuracy: 0.8789 - val_loss: 0.3672 - val_accuracy: 0.8517
# Epoch 112/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3454 - accuracy: 0.8778 - val_loss: 0.3613 - val_accuracy: 0.8500
# Epoch 113/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3438 - accuracy: 0.8791 - val_loss: 0.3675 - val_accuracy: 0.8583
# Epoch 114/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3436 - accuracy: 0.8784 - val_loss: 0.3624 - val_accuracy: 0.8483
# Epoch 115/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3426 - accuracy: 0.8791 - val_loss: 0.3591 - val_accuracy: 0.8500
# Epoch 116/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3417 - accuracy: 0.8800 - val_loss: 0.3677 - val_accuracy: 0.8583
# Epoch 117/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3413 - accuracy: 0.8791 - val_loss: 0.3582 - val_accuracy: 0.8583
# Epoch 118/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3405 - accuracy: 0.8807 - val_loss: 0.3577 - val_accuracy: 0.8550
# Epoch 119/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3393 - accuracy: 0.8809 - val_loss: 0.3560 - val_accuracy: 0.8533
# Epoch 120/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3384 - accuracy: 0.8805 - val_loss: 0.3619 - val_accuracy: 0.8567
# Epoch 121/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3378 - accuracy: 0.8806 - val_loss: 0.3597 - val_accuracy: 0.8550
# Epoch 122/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3388 - accuracy: 0.8805 - val_loss: 0.3601 - val_accuracy: 0.8533
# Epoch 123/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3368 - accuracy: 0.8815 - val_loss: 0.3561 - val_accuracy: 0.8583
# Epoch 124/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3362 - accuracy: 0.8816 - val_loss: 0.3573 - val_accuracy: 0.8483
# Epoch 125/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3359 - accuracy: 0.8817 - val_loss: 0.3551 - val_accuracy: 0.8550
# Epoch 126/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3359 - accuracy: 0.8818 - val_loss: 0.3535 - val_accuracy: 0.8583
# Epoch 127/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3346 - accuracy: 0.8820 - val_loss: 0.3600 - val_accuracy: 0.8533
# Epoch 128/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3334 - accuracy: 0.8827 - val_loss: 0.3543 - val_accuracy: 0.8517
# Epoch 129/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3337 - accuracy: 0.8823 - val_loss: 0.3536 - val_accuracy: 0.8583
# Epoch 130/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3322 - accuracy: 0.8825 - val_loss: 0.3501 - val_accuracy: 0.8533
# Epoch 131/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3315 - accuracy: 0.8828 - val_loss: 0.3571 - val_accuracy: 0.8583
# Epoch 132/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3307 - accuracy: 0.8833 - val_loss: 0.3529 - val_accuracy: 0.8533
# Epoch 133/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3302 - accuracy: 0.8832 - val_loss: 0.3504 - val_accuracy: 0.8600
# Epoch 134/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3305 - accuracy: 0.8834 - val_loss: 0.3538 - val_accuracy: 0.8533
# Epoch 135/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3296 - accuracy: 0.8841 - val_loss: 0.3523 - val_accuracy: 0.8600
# Epoch 136/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3288 - accuracy: 0.8843 - val_loss: 0.3519 - val_accuracy: 0.8500
# Epoch 137/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3292 - accuracy: 0.8837 - val_loss: 0.3498 - val_accuracy: 0.8550
# Epoch 138/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3282 - accuracy: 0.8839 - val_loss: 0.3508 - val_accuracy: 0.8583
# Epoch 139/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3284 - accuracy: 0.8842 - val_loss: 0.3515 - val_accuracy: 0.8583
# Epoch 140/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3262 - accuracy: 0.8846 - val_loss: 0.3463 - val_accuracy: 0.8600
# Epoch 141/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3263 - accuracy: 0.8843 - val_loss: 0.3508 - val_accuracy: 0.8533
# Epoch 142/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3256 - accuracy: 0.8845 - val_loss: 0.3468 - val_accuracy: 0.8567
# Epoch 143/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3251 - accuracy: 0.8858 - val_loss: 0.3502 - val_accuracy: 0.8550
# Epoch 144/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3248 - accuracy: 0.8853 - val_loss: 0.3486 - val_accuracy: 0.8583
# Epoch 145/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3238 - accuracy: 0.8859 - val_loss: 0.3461 - val_accuracy: 0.8583
# Epoch 146/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3230 - accuracy: 0.8856 - val_loss: 0.3475 - val_accuracy: 0.8517
# Epoch 147/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3219 - accuracy: 0.8865 - val_loss: 0.3447 - val_accuracy: 0.8567
# Epoch 148/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3218 - accuracy: 0.8860 - val_loss: 0.3441 - val_accuracy: 0.8567
# Epoch 149/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3219 - accuracy: 0.8866 - val_loss: 0.3481 - val_accuracy: 0.8600
# Epoch 150/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3201 - accuracy: 0.8869 - val_loss: 0.3421 - val_accuracy: 0.8633
# Epoch 151/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3196 - accuracy: 0.8871 - val_loss: 0.3428 - val_accuracy: 0.8617
# Epoch 152/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3192 - accuracy: 0.8870 - val_loss: 0.3426 - val_accuracy: 0.8733
# Epoch 153/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3191 - accuracy: 0.8872 - val_loss: 0.3447 - val_accuracy: 0.8567
# Epoch 154/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3197 - accuracy: 0.8869 - val_loss: 0.3386 - val_accuracy: 0.8650
# Epoch 155/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3179 - accuracy: 0.8876 - val_loss: 0.3455 - val_accuracy: 0.8650
# Epoch 156/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3175 - accuracy: 0.8875 - val_loss: 0.3410 - val_accuracy: 0.8617
# Epoch 157/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3162 - accuracy: 0.8883 - val_loss: 0.3403 - val_accuracy: 0.8617
# Epoch 158/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3172 - accuracy: 0.8878 - val_loss: 0.3453 - val_accuracy: 0.8583
# Epoch 159/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3152 - accuracy: 0.8878 - val_loss: 0.3399 - val_accuracy: 0.8667
# Epoch 160/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3148 - accuracy: 0.8884 - val_loss: 0.3393 - val_accuracy: 0.8650
# Epoch 161/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3147 - accuracy: 0.8881 - val_loss: 0.3453 - val_accuracy: 0.8667
# Epoch 162/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3141 - accuracy: 0.8895 - val_loss: 0.3398 - val_accuracy: 0.8633
# Epoch 163/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3132 - accuracy: 0.8889 - val_loss: 0.3379 - val_accuracy: 0.8617
# Epoch 164/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3130 - accuracy: 0.8893 - val_loss: 0.3470 - val_accuracy: 0.8567
# Epoch 165/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3124 - accuracy: 0.8893 - val_loss: 0.3410 - val_accuracy: 0.8667
# Epoch 166/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3110 - accuracy: 0.8898 - val_loss: 0.3364 - val_accuracy: 0.8700
# Epoch 167/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3113 - accuracy: 0.8894 - val_loss: 0.3357 - val_accuracy: 0.8700
# Epoch 168/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3104 - accuracy: 0.8901 - val_loss: 0.3387 - val_accuracy: 0.8750
# Epoch 169/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3111 - accuracy: 0.8895 - val_loss: 0.3388 - val_accuracy: 0.8683
# Epoch 170/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3090 - accuracy: 0.8904 - val_loss: 0.3414 - val_accuracy: 0.8683
# Epoch 171/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3092 - accuracy: 0.8903 - val_loss: 0.3438 - val_accuracy: 0.8617
# Epoch 172/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3114 - accuracy: 0.8891 - val_loss: 0.3422 - val_accuracy: 0.8600
# Epoch 173/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3082 - accuracy: 0.8905 - val_loss: 0.3366 - val_accuracy: 0.8667
# Epoch 174/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3069 - accuracy: 0.8912 - val_loss: 0.3375 - val_accuracy: 0.8633
# Epoch 175/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3068 - accuracy: 0.8912 - val_loss: 0.3324 - val_accuracy: 0.8700
# Epoch 176/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3062 - accuracy: 0.8915 - val_loss: 0.3344 - val_accuracy: 0.8683
# Epoch 177/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3058 - accuracy: 0.8917 - val_loss: 0.3379 - val_accuracy: 0.8633
# Epoch 178/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3057 - accuracy: 0.8917 - val_loss: 0.3405 - val_accuracy: 0.8600
# Epoch 179/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.3060 - accuracy: 0.8913 - val_loss: 0.3352 - val_accuracy: 0.8733
# Epoch 180/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3042 - accuracy: 0.8921 - val_loss: 0.3335 - val_accuracy: 0.8767
# Epoch 181/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3040 - accuracy: 0.8919 - val_loss: 0.3359 - val_accuracy: 0.8650
# Epoch 182/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3034 - accuracy: 0.8922 - val_loss: 0.3318 - val_accuracy: 0.8700
# Epoch 183/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3026 - accuracy: 0.8925 - val_loss: 0.3325 - val_accuracy: 0.8667
# Epoch 184/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3028 - accuracy: 0.8925 - val_loss: 0.3335 - val_accuracy: 0.8733
# Epoch 185/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3033 - accuracy: 0.8926 - val_loss: 0.3319 - val_accuracy: 0.8683
# Epoch 186/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3017 - accuracy: 0.8927 - val_loss: 0.3313 - val_accuracy: 0.8700
# Epoch 187/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3015 - accuracy: 0.8932 - val_loss: 0.3317 - val_accuracy: 0.8683
# Epoch 188/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3000 - accuracy: 0.8929 - val_loss: 0.3339 - val_accuracy: 0.8683
# Epoch 189/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2997 - accuracy: 0.8938 - val_loss: 0.3277 - val_accuracy: 0.8650
# Epoch 190/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3012 - accuracy: 0.8928 - val_loss: 0.3315 - val_accuracy: 0.8650
# Epoch 191/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.2988 - accuracy: 0.8940 - val_loss: 0.3300 - val_accuracy: 0.8733
# Epoch 192/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.2989 - accuracy: 0.8937 - val_loss: 0.3348 - val_accuracy: 0.8700
# Epoch 193/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.2987 - accuracy: 0.8937 - val_loss: 0.3343 - val_accuracy: 0.8683
# Epoch 194/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.2980 - accuracy: 0.8936 - val_loss: 0.3336 - val_accuracy: 0.8700
# Epoch 195/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2966 - accuracy: 0.8949 - val_loss: 0.3308 - val_accuracy: 0.8700
# Epoch 196/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2963 - accuracy: 0.8944 - val_loss: 0.3272 - val_accuracy: 0.8733
# Epoch 197/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.2979 - accuracy: 0.8943 - val_loss: 0.3325 - val_accuracy: 0.8767
# Epoch 198/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.2969 - accuracy: 0.8943 - val_loss: 0.3265 - val_accuracy: 0.8683
# Epoch 199/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2951 - accuracy: 0.8954 - val_loss: 0.3264 - val_accuracy: 0.8700
# Epoch 200/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.2950 - accuracy: 0.8950 - val_loss: 0.3256 - val_accuracy: 0.8683

# %%
# loss 값을 plot 해보겠습니다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.title('Loss graph without dropout layer') 
plt.ylim(0,1)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다.
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accuracy graph without dropout layer') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# dropout layer가 없는 fully connected layer에서 200번 정도의 학습을 하니 train set의 accuracy는 올라가고, loss는 점점 떨어졌습니다. 그러나 validation set의 accuracy와 loss는 어느 정도 값에서 수렴함을 볼 수 있었습니다.
# 이렇게 오버피팅을 만든 환경에서 dropout layer를 추가한 뒤 나머지 환경은 같게 한 실험을 살펴보도록 하겠습니다.

# %%
# Q. dropout layer를 추가해보세요. (dropout 확률은 0.5로 지정해주세요.)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    # 여기에 dropout layer를 추가해보았습니다. 나머지 layer는 위의 실습과 같습니다. 
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=200, batch_size=512, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 117/117 [==============================] - 5s 35ms/step - loss: 2.0789 - accuracy: 0.4832 - val_loss: 1.6973 - val_accuracy: 0.5867
# Epoch 2/200
# 117/117 [==============================] - 4s 31ms/step - loss: 1.4787 - accuracy: 0.5463 - val_loss: 1.2393 - val_accuracy: 0.6350
# Epoch 3/200
# 117/117 [==============================] - 4s 32ms/step - loss: 1.1788 - accuracy: 0.6132 - val_loss: 1.0305 - val_accuracy: 0.7017
# Epoch 4/200
# 117/117 [==============================] - 4s 31ms/step - loss: 1.0125 - accuracy: 0.6631 - val_loss: 0.9006 - val_accuracy: 0.7417
# Epoch 5/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.9101 - accuracy: 0.6902 - val_loss: 0.8106 - val_accuracy: 0.7500
# Epoch 6/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.8381 - accuracy: 0.7079 - val_loss: 0.7511 - val_accuracy: 0.7700
# Epoch 7/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.7874 - accuracy: 0.7208 - val_loss: 0.7113 - val_accuracy: 0.7633
# Epoch 8/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.7492 - accuracy: 0.7308 - val_loss: 0.6795 - val_accuracy: 0.7850
# Epoch 9/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.7224 - accuracy: 0.7420 - val_loss: 0.6532 - val_accuracy: 0.7883
# Epoch 10/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.6989 - accuracy: 0.7478 - val_loss: 0.6350 - val_accuracy: 0.7867
# Epoch 11/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.6791 - accuracy: 0.7532 - val_loss: 0.6146 - val_accuracy: 0.7950
# Epoch 12/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.6609 - accuracy: 0.7603 - val_loss: 0.6031 - val_accuracy: 0.7933
# Epoch 13/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.6431 - accuracy: 0.7675 - val_loss: 0.5899 - val_accuracy: 0.7950
# Epoch 14/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.6286 - accuracy: 0.7727 - val_loss: 0.5754 - val_accuracy: 0.7950
# Epoch 15/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.6161 - accuracy: 0.7777 - val_loss: 0.5642 - val_accuracy: 0.8033
# Epoch 16/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.6054 - accuracy: 0.7811 - val_loss: 0.5558 - val_accuracy: 0.7983
# Epoch 17/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5934 - accuracy: 0.7865 - val_loss: 0.5463 - val_accuracy: 0.8017
# Epoch 18/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5857 - accuracy: 0.7908 - val_loss: 0.5379 - val_accuracy: 0.8000
# Epoch 19/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.5731 - accuracy: 0.7966 - val_loss: 0.5318 - val_accuracy: 0.8000
# Epoch 20/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.5679 - accuracy: 0.7963 - val_loss: 0.5230 - val_accuracy: 0.8033
# Epoch 21/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.5590 - accuracy: 0.7997 - val_loss: 0.5166 - val_accuracy: 0.8050
# Epoch 22/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.5509 - accuracy: 0.8033 - val_loss: 0.5104 - val_accuracy: 0.8050
# Epoch 23/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5438 - accuracy: 0.8069 - val_loss: 0.5039 - val_accuracy: 0.8117
# Epoch 24/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5369 - accuracy: 0.8098 - val_loss: 0.4984 - val_accuracy: 0.8117
# Epoch 25/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5316 - accuracy: 0.8105 - val_loss: 0.4929 - val_accuracy: 0.8167
# Epoch 26/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.5247 - accuracy: 0.8135 - val_loss: 0.4891 - val_accuracy: 0.8133
# Epoch 27/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5223 - accuracy: 0.8148 - val_loss: 0.4851 - val_accuracy: 0.8167
# Epoch 28/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.5147 - accuracy: 0.8167 - val_loss: 0.4811 - val_accuracy: 0.8117
# Epoch 29/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.5123 - accuracy: 0.8174 - val_loss: 0.4762 - val_accuracy: 0.8217
# Epoch 30/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.5068 - accuracy: 0.8187 - val_loss: 0.4712 - val_accuracy: 0.8183
# Epoch 31/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.5012 - accuracy: 0.8220 - val_loss: 0.4659 - val_accuracy: 0.8200
# Epoch 32/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4982 - accuracy: 0.8237 - val_loss: 0.4642 - val_accuracy: 0.8183
# Epoch 33/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4929 - accuracy: 0.8247 - val_loss: 0.4608 - val_accuracy: 0.8167
# Epoch 34/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4892 - accuracy: 0.8257 - val_loss: 0.4585 - val_accuracy: 0.8183
# Epoch 35/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4856 - accuracy: 0.8269 - val_loss: 0.4531 - val_accuracy: 0.8183
# Epoch 36/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4824 - accuracy: 0.8294 - val_loss: 0.4497 - val_accuracy: 0.8150
# Epoch 37/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.4806 - accuracy: 0.8288 - val_loss: 0.4500 - val_accuracy: 0.8217
# Epoch 38/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4740 - accuracy: 0.8322 - val_loss: 0.4438 - val_accuracy: 0.8250
# Epoch 39/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4733 - accuracy: 0.8330 - val_loss: 0.4405 - val_accuracy: 0.8300
# Epoch 40/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4705 - accuracy: 0.8325 - val_loss: 0.4376 - val_accuracy: 0.8283
# Epoch 41/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4672 - accuracy: 0.8341 - val_loss: 0.4357 - val_accuracy: 0.8317
# Epoch 42/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4654 - accuracy: 0.8353 - val_loss: 0.4356 - val_accuracy: 0.8333
# Epoch 43/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4613 - accuracy: 0.8370 - val_loss: 0.4337 - val_accuracy: 0.8283
# Epoch 44/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.4584 - accuracy: 0.8380 - val_loss: 0.4286 - val_accuracy: 0.8333
# Epoch 45/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4564 - accuracy: 0.8371 - val_loss: 0.4244 - val_accuracy: 0.8300
# Epoch 46/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.4549 - accuracy: 0.8393 - val_loss: 0.4260 - val_accuracy: 0.8300
# Epoch 47/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.4511 - accuracy: 0.8403 - val_loss: 0.4244 - val_accuracy: 0.8317
# Epoch 48/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4490 - accuracy: 0.8410 - val_loss: 0.4221 - val_accuracy: 0.8333
# Epoch 49/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4473 - accuracy: 0.8424 - val_loss: 0.4184 - val_accuracy: 0.8300
# Epoch 50/200
# 117/117 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.84 - 4s 32ms/step - loss: 0.4439 - accuracy: 0.8449 - val_loss: 0.4165 - val_accuracy: 0.8383
# Epoch 51/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4423 - accuracy: 0.8434 - val_loss: 0.4141 - val_accuracy: 0.8317
# Epoch 52/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4404 - accuracy: 0.8442 - val_loss: 0.4154 - val_accuracy: 0.8383
# Epoch 53/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4401 - accuracy: 0.8448 - val_loss: 0.4149 - val_accuracy: 0.8317
# Epoch 54/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4374 - accuracy: 0.8450 - val_loss: 0.4115 - val_accuracy: 0.8350
# Epoch 55/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4363 - accuracy: 0.8456 - val_loss: 0.4108 - val_accuracy: 0.8383
# Epoch 56/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4326 - accuracy: 0.8482 - val_loss: 0.4057 - val_accuracy: 0.8383
# Epoch 57/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.4311 - accuracy: 0.8462 - val_loss: 0.4019 - val_accuracy: 0.8333
# Epoch 58/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4292 - accuracy: 0.8470 - val_loss: 0.4059 - val_accuracy: 0.8300
# Epoch 59/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4293 - accuracy: 0.8481 - val_loss: 0.4047 - val_accuracy: 0.8317
# Epoch 60/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4262 - accuracy: 0.8491 - val_loss: 0.4016 - val_accuracy: 0.8333
# Epoch 61/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4250 - accuracy: 0.8494 - val_loss: 0.4011 - val_accuracy: 0.8383
# Epoch 62/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4231 - accuracy: 0.8505 - val_loss: 0.3990 - val_accuracy: 0.8400
# Epoch 63/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4213 - accuracy: 0.8520 - val_loss: 0.3955 - val_accuracy: 0.8383
# Epoch 64/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4194 - accuracy: 0.8524 - val_loss: 0.3950 - val_accuracy: 0.8433
# Epoch 65/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4189 - accuracy: 0.8518 - val_loss: 0.3951 - val_accuracy: 0.8383
# Epoch 66/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4156 - accuracy: 0.8527 - val_loss: 0.3918 - val_accuracy: 0.8450
# Epoch 67/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4148 - accuracy: 0.8535 - val_loss: 0.3921 - val_accuracy: 0.8433
# Epoch 68/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4140 - accuracy: 0.8546 - val_loss: 0.3881 - val_accuracy: 0.8467
# Epoch 69/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.4127 - accuracy: 0.8530 - val_loss: 0.3868 - val_accuracy: 0.8450
# Epoch 70/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4120 - accuracy: 0.8546 - val_loss: 0.3878 - val_accuracy: 0.8433
# Epoch 71/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.4115 - accuracy: 0.8548 - val_loss: 0.3852 - val_accuracy: 0.8400
# Epoch 72/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4085 - accuracy: 0.8561 - val_loss: 0.3847 - val_accuracy: 0.8417
# Epoch 73/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4080 - accuracy: 0.8552 - val_loss: 0.3830 - val_accuracy: 0.8450
# Epoch 74/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4060 - accuracy: 0.8563 - val_loss: 0.3817 - val_accuracy: 0.8517
# Epoch 75/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4057 - accuracy: 0.8562 - val_loss: 0.3829 - val_accuracy: 0.8433
# Epoch 76/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4034 - accuracy: 0.8577 - val_loss: 0.3813 - val_accuracy: 0.8450
# Epoch 77/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4025 - accuracy: 0.8584 - val_loss: 0.3790 - val_accuracy: 0.8483
# Epoch 78/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4019 - accuracy: 0.8571 - val_loss: 0.3795 - val_accuracy: 0.8433
# Epoch 79/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3992 - accuracy: 0.8596 - val_loss: 0.3756 - val_accuracy: 0.8500
# Epoch 80/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3981 - accuracy: 0.8580 - val_loss: 0.3754 - val_accuracy: 0.8533
# Epoch 81/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3991 - accuracy: 0.8595 - val_loss: 0.3794 - val_accuracy: 0.8433
# Epoch 82/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3959 - accuracy: 0.8596 - val_loss: 0.3755 - val_accuracy: 0.8500
# Epoch 83/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3962 - accuracy: 0.8597 - val_loss: 0.3756 - val_accuracy: 0.8467
# Epoch 84/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3961 - accuracy: 0.8595 - val_loss: 0.3733 - val_accuracy: 0.8533
# Epoch 85/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3933 - accuracy: 0.8603 - val_loss: 0.3724 - val_accuracy: 0.8500
# Epoch 86/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3943 - accuracy: 0.8616 - val_loss: 0.3708 - val_accuracy: 0.8483
# Epoch 87/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3925 - accuracy: 0.8600 - val_loss: 0.3724 - val_accuracy: 0.8517
# Epoch 88/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.3903 - accuracy: 0.8611 - val_loss: 0.3700 - val_accuracy: 0.8483
# Epoch 89/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3891 - accuracy: 0.8621 - val_loss: 0.3720 - val_accuracy: 0.8567
# Epoch 90/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3902 - accuracy: 0.8632 - val_loss: 0.3693 - val_accuracy: 0.8533
# Epoch 91/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3887 - accuracy: 0.8634 - val_loss: 0.3696 - val_accuracy: 0.8517
# Epoch 92/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3856 - accuracy: 0.8640 - val_loss: 0.3661 - val_accuracy: 0.8500
# Epoch 93/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3855 - accuracy: 0.8638 - val_loss: 0.3658 - val_accuracy: 0.8483
# Epoch 94/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3858 - accuracy: 0.8641 - val_loss: 0.3657 - val_accuracy: 0.8550
# Epoch 95/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3850 - accuracy: 0.8640 - val_loss: 0.3642 - val_accuracy: 0.8550
# Epoch 96/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3828 - accuracy: 0.8654 - val_loss: 0.3653 - val_accuracy: 0.8533
# Epoch 97/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3818 - accuracy: 0.8653 - val_loss: 0.3636 - val_accuracy: 0.8533
# Epoch 98/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3824 - accuracy: 0.8661 - val_loss: 0.3630 - val_accuracy: 0.8533
# Epoch 99/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3805 - accuracy: 0.8653 - val_loss: 0.3631 - val_accuracy: 0.8583
# Epoch 100/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3783 - accuracy: 0.8660 - val_loss: 0.3597 - val_accuracy: 0.8533
# Epoch 101/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3803 - accuracy: 0.8659 - val_loss: 0.3617 - val_accuracy: 0.8550
# Epoch 102/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3783 - accuracy: 0.8663 - val_loss: 0.3617 - val_accuracy: 0.8567
# Epoch 103/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3760 - accuracy: 0.8665 - val_loss: 0.3574 - val_accuracy: 0.8650
# Epoch 104/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3743 - accuracy: 0.8676 - val_loss: 0.3590 - val_accuracy: 0.8633
# Epoch 105/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3745 - accuracy: 0.8681 - val_loss: 0.3590 - val_accuracy: 0.8600
# Epoch 106/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3769 - accuracy: 0.8670 - val_loss: 0.3562 - val_accuracy: 0.8617
# Epoch 107/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3743 - accuracy: 0.8684 - val_loss: 0.3572 - val_accuracy: 0.8600
# Epoch 108/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3736 - accuracy: 0.8681 - val_loss: 0.3537 - val_accuracy: 0.8583
# Epoch 109/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3719 - accuracy: 0.8695 - val_loss: 0.3543 - val_accuracy: 0.8600
# Epoch 110/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3730 - accuracy: 0.8682 - val_loss: 0.3558 - val_accuracy: 0.8617
# Epoch 111/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3715 - accuracy: 0.8688 - val_loss: 0.3549 - val_accuracy: 0.8617
# Epoch 112/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3691 - accuracy: 0.8693 - val_loss: 0.3521 - val_accuracy: 0.8533
# Epoch 113/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3702 - accuracy: 0.8699 - val_loss: 0.3520 - val_accuracy: 0.8650
# Epoch 114/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3694 - accuracy: 0.8698 - val_loss: 0.3510 - val_accuracy: 0.8583
# Epoch 115/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3682 - accuracy: 0.8694 - val_loss: 0.3493 - val_accuracy: 0.8633
# Epoch 116/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3680 - accuracy: 0.8697 - val_loss: 0.3523 - val_accuracy: 0.8567
# Epoch 117/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3671 - accuracy: 0.8707 - val_loss: 0.3508 - val_accuracy: 0.8633
# Epoch 118/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3652 - accuracy: 0.8713 - val_loss: 0.3511 - val_accuracy: 0.8667
# Epoch 119/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3672 - accuracy: 0.8717 - val_loss: 0.3475 - val_accuracy: 0.8667
# Epoch 120/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3655 - accuracy: 0.8709 - val_loss: 0.3494 - val_accuracy: 0.8583
# Epoch 121/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3620 - accuracy: 0.8721 - val_loss: 0.3490 - val_accuracy: 0.8650
# Epoch 122/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3654 - accuracy: 0.8719 - val_loss: 0.3461 - val_accuracy: 0.8600
# Epoch 123/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3620 - accuracy: 0.8708 - val_loss: 0.3491 - val_accuracy: 0.8567
# Epoch 124/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3627 - accuracy: 0.8710 - val_loss: 0.3501 - val_accuracy: 0.8617
# Epoch 125/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3610 - accuracy: 0.8714 - val_loss: 0.3460 - val_accuracy: 0.8617
# Epoch 126/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3602 - accuracy: 0.8729 - val_loss: 0.3440 - val_accuracy: 0.8633
# Epoch 127/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3592 - accuracy: 0.8729 - val_loss: 0.3463 - val_accuracy: 0.8667
# Epoch 128/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3584 - accuracy: 0.8725 - val_loss: 0.3445 - val_accuracy: 0.8617
# Epoch 129/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3580 - accuracy: 0.8743 - val_loss: 0.3455 - val_accuracy: 0.8600
# Epoch 130/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3593 - accuracy: 0.8733 - val_loss: 0.3441 - val_accuracy: 0.8583
# Epoch 131/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3580 - accuracy: 0.8736 - val_loss: 0.3442 - val_accuracy: 0.8633
# Epoch 132/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3562 - accuracy: 0.8747 - val_loss: 0.3446 - val_accuracy: 0.8617
# Epoch 133/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3544 - accuracy: 0.8741 - val_loss: 0.3413 - val_accuracy: 0.8683
# Epoch 134/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3566 - accuracy: 0.8738 - val_loss: 0.3426 - val_accuracy: 0.8600
# Epoch 135/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3569 - accuracy: 0.8736 - val_loss: 0.3413 - val_accuracy: 0.8683
# Epoch 136/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.3537 - accuracy: 0.8738 - val_loss: 0.3414 - val_accuracy: 0.8600
# Epoch 137/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3557 - accuracy: 0.8745 - val_loss: 0.3404 - val_accuracy: 0.8650
# Epoch 138/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3516 - accuracy: 0.8751 - val_loss: 0.3428 - val_accuracy: 0.8667
# Epoch 139/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3507 - accuracy: 0.8764 - val_loss: 0.3383 - val_accuracy: 0.8633
# Epoch 140/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3531 - accuracy: 0.8749 - val_loss: 0.3386 - val_accuracy: 0.8667
# Epoch 141/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3528 - accuracy: 0.8757 - val_loss: 0.3395 - val_accuracy: 0.8617
# Epoch 142/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3517 - accuracy: 0.8756 - val_loss: 0.3363 - val_accuracy: 0.8650
# Epoch 143/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3508 - accuracy: 0.8768 - val_loss: 0.3402 - val_accuracy: 0.8633
# Epoch 144/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3496 - accuracy: 0.8764 - val_loss: 0.3367 - val_accuracy: 0.8633
# Epoch 145/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3481 - accuracy: 0.8756 - val_loss: 0.3342 - val_accuracy: 0.8683
# Epoch 146/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3509 - accuracy: 0.8747 - val_loss: 0.3374 - val_accuracy: 0.8617
# Epoch 147/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3488 - accuracy: 0.8769 - val_loss: 0.3358 - val_accuracy: 0.8650
# Epoch 148/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3482 - accuracy: 0.8764 - val_loss: 0.3373 - val_accuracy: 0.8617
# Epoch 149/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3454 - accuracy: 0.8779 - val_loss: 0.3357 - val_accuracy: 0.8683
# Epoch 150/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3452 - accuracy: 0.8784 - val_loss: 0.3344 - val_accuracy: 0.8683
# Epoch 151/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3452 - accuracy: 0.8773 - val_loss: 0.3350 - val_accuracy: 0.8583
# Epoch 152/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3458 - accuracy: 0.8782 - val_loss: 0.3348 - val_accuracy: 0.8667
# Epoch 153/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3457 - accuracy: 0.8775 - val_loss: 0.3337 - val_accuracy: 0.8700
# Epoch 154/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3441 - accuracy: 0.8772 - val_loss: 0.3330 - val_accuracy: 0.8617
# Epoch 155/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3461 - accuracy: 0.8769 - val_loss: 0.3366 - val_accuracy: 0.8667
# Epoch 156/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.3445 - accuracy: 0.8778 - val_loss: 0.3298 - val_accuracy: 0.8650
# Epoch 157/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3424 - accuracy: 0.8792 - val_loss: 0.3306 - val_accuracy: 0.8617
# Epoch 158/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3432 - accuracy: 0.8788 - val_loss: 0.3310 - val_accuracy: 0.8733
# Epoch 159/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3423 - accuracy: 0.8786 - val_loss: 0.3321 - val_accuracy: 0.8717
# Epoch 160/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3405 - accuracy: 0.8796 - val_loss: 0.3361 - val_accuracy: 0.8617
# Epoch 161/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3429 - accuracy: 0.8785 - val_loss: 0.3318 - val_accuracy: 0.8667
# Epoch 162/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3412 - accuracy: 0.8798 - val_loss: 0.3332 - val_accuracy: 0.8683
# Epoch 163/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3403 - accuracy: 0.8797 - val_loss: 0.3313 - val_accuracy: 0.8667
# Epoch 164/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3392 - accuracy: 0.8799 - val_loss: 0.3306 - val_accuracy: 0.8633
# Epoch 165/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3387 - accuracy: 0.8801 - val_loss: 0.3303 - val_accuracy: 0.8650
# Epoch 166/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3391 - accuracy: 0.8799 - val_loss: 0.3280 - val_accuracy: 0.8633
# Epoch 167/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3385 - accuracy: 0.8801 - val_loss: 0.3281 - val_accuracy: 0.8650
# Epoch 168/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3378 - accuracy: 0.8797 - val_loss: 0.3274 - val_accuracy: 0.8600
# Epoch 169/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3370 - accuracy: 0.8805 - val_loss: 0.3278 - val_accuracy: 0.8617
# Epoch 170/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3360 - accuracy: 0.8807 - val_loss: 0.3314 - val_accuracy: 0.8633
# Epoch 171/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3383 - accuracy: 0.8796 - val_loss: 0.3270 - val_accuracy: 0.8700
# Epoch 172/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3364 - accuracy: 0.8794 - val_loss: 0.3260 - val_accuracy: 0.8650
# Epoch 173/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3366 - accuracy: 0.8818 - val_loss: 0.3270 - val_accuracy: 0.8650
# Epoch 174/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3346 - accuracy: 0.8809 - val_loss: 0.3282 - val_accuracy: 0.8700
# Epoch 175/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3339 - accuracy: 0.8824 - val_loss: 0.3257 - val_accuracy: 0.8700
# Epoch 176/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3331 - accuracy: 0.8808 - val_loss: 0.3261 - val_accuracy: 0.8650
# Epoch 177/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3328 - accuracy: 0.8809 - val_loss: 0.3273 - val_accuracy: 0.8667
# Epoch 178/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3349 - accuracy: 0.8813 - val_loss: 0.3309 - val_accuracy: 0.8650
# Epoch 179/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3330 - accuracy: 0.8827 - val_loss: 0.3270 - val_accuracy: 0.8683
# Epoch 180/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3310 - accuracy: 0.8822 - val_loss: 0.3258 - val_accuracy: 0.8667
# Epoch 181/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3330 - accuracy: 0.8820 - val_loss: 0.3270 - val_accuracy: 0.8633
# Epoch 182/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3312 - accuracy: 0.8821 - val_loss: 0.3238 - val_accuracy: 0.8667
# Epoch 183/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3307 - accuracy: 0.8830 - val_loss: 0.3254 - val_accuracy: 0.8733
# Epoch 184/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3286 - accuracy: 0.8837 - val_loss: 0.3220 - val_accuracy: 0.8683
# Epoch 185/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3300 - accuracy: 0.8821 - val_loss: 0.3234 - val_accuracy: 0.8717
# Epoch 186/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3302 - accuracy: 0.8826 - val_loss: 0.3265 - val_accuracy: 0.8650
# Epoch 187/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3303 - accuracy: 0.8825 - val_loss: 0.3231 - val_accuracy: 0.8633
# Epoch 188/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3283 - accuracy: 0.8841 - val_loss: 0.3244 - val_accuracy: 0.8700
# Epoch 189/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3298 - accuracy: 0.8838 - val_loss: 0.3243 - val_accuracy: 0.8667
# Epoch 190/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3262 - accuracy: 0.8843 - val_loss: 0.3239 - val_accuracy: 0.8683
# Epoch 191/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3279 - accuracy: 0.8838 - val_loss: 0.3204 - val_accuracy: 0.8683
# Epoch 192/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3287 - accuracy: 0.8825 - val_loss: 0.3216 - val_accuracy: 0.8750
# Epoch 193/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3266 - accuracy: 0.8844 - val_loss: 0.3224 - val_accuracy: 0.8700
# Epoch 194/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3246 - accuracy: 0.8826 - val_loss: 0.3233 - val_accuracy: 0.8667
# Epoch 195/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3253 - accuracy: 0.8848 - val_loss: 0.3213 - val_accuracy: 0.8700
# Epoch 196/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3247 - accuracy: 0.8846 - val_loss: 0.3209 - val_accuracy: 0.8733
# Epoch 197/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3232 - accuracy: 0.8852 - val_loss: 0.3220 - val_accuracy: 0.8600
# Epoch 198/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3268 - accuracy: 0.8832 - val_loss: 0.3182 - val_accuracy: 0.8750
# Epoch 199/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3237 - accuracy: 0.8851 - val_loss: 0.3211 - val_accuracy: 0.8717
# Epoch 200/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3243 - accuracy: 0.8851 - val_loss: 0.3225 - val_accuracy: 0.8667

# %%
# Q. loss 값의 그래프를 그려봅시다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph with dropout layer') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# Q. accuracy 값의 그래프를 그려봅시다. 
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accuracy graph with dropout layer') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# 좋은 데이터를 가지고 오버피팅을 만드는 환경이 조금 어렵긴 했지만, dropout layer 하나만으로도 오버피팅을 막고, 두 데이터 셋이 정확도도 비슷하게 나옴을 확인하였습니다. 사실 더 복잡한 네트워크나, 더 어려운 데이터의 경우에는 이러한 오버피팅이 더 자주 있는 일이므로, dropout layer를 추가하는 경우가 많습니다. 하지만 이 또한 확률 값이 파라미터로 들어가므로, 어떠한 값을 선택하느냐는 데이터와 네트워크에 따라 달린 일입니다.

# %% [markdown]
# ## 7-7. Batch Normalization
#
# 논문 제목 : Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift
# 논문 발표 시점 : 2015년
# 논문 링크 : 논문 PDF (http://arxiv.org/pdf/1502.03167)
# (batch normalization과 internal covariate shift가 연관성이 없다는 반론(https://arxiv.org/pdf/1805.11604)도 있기 때문에, "이런 이야기도 있구나~" 하고 받아들이시면 됩니다.)
#
# 딥러닝에서 경사 하강법(gradient descent)으로 모델의 가중치를 업데이트할 때, 데이터셋 전체를 본 다음 업데이트하는 'Batch Gradient Descent'와 데이터 하나를 관찰할 때마다 업데이트하는 'Stochastic Gradient Descent' 방법이 있었죠. 이 둘의 절충안이 바로 데이터셋을 여러 개의 mini-batch로 쪼갠 다음 하나의 batch를 처리할 때마다 가중치를 업데이트하는 'Mini-batch Gradient Descent'입니다. 데이터셋을 mini-batch로 쪼개는 방법은 학습 속도와 안정성 모두를 잡았지만, 딥러닝 모델 안에서 데이터가 처리되면서 여러 개의 mini-batch들 사이에 데이터 분포의 차이가 생길 수 있다는 문제가 있었습니다. (이것이 internal covariate shift를 대략적으로 설명한 부분입니다.)
#
# 데이터 분포의 차이가 존재한다면 gradient 값의 차이도 있을 것이고, 같은 learning rate 값을 가지고 있더라도 gradient vanishing이나 gradient explode 문제가 생길 수 있습니다. batch normalization 기법은 각 mini-batch마다 평균과 분산을 계산하여 정규화(normalization)를 수행하고, scale and shift 변환을 적용하여 mini-batch들이 비슷한 데이터 분포를 가지도록 합니다.
#
# 논문에서 설명한 알고리즘을 아래에 적어보도록 하겠습니다.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ### 실습
# ---
# 아무것도 하지 않은 fully connected layer와 batch normalization layer를 추가한 두 실험을 비교하고자 합니다. 중점적으로 봐야 할 내용은 정확도 비교와 속도의 차이입니다.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = keras.datasets.fashion_mnist
print('=3')
# Out:
# =3

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.3, random_state=101)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(X_train, y_train, epochs=20, batch_size=2048, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 21/21 [==============================] - 2s 49ms/step - loss: 1.2535 - accuracy: 0.5873 - val_loss: 0.7648 - val_accuracy: 0.7396
# Epoch 2/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.6702 - accuracy: 0.7697 - val_loss: 0.6082 - val_accuracy: 0.7949
# Epoch 3/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5658 - accuracy: 0.8103 - val_loss: 0.5419 - val_accuracy: 0.8165
# Epoch 4/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5148 - accuracy: 0.8267 - val_loss: 0.5080 - val_accuracy: 0.8267
# Epoch 5/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.4838 - accuracy: 0.8365 - val_loss: 0.4806 - val_accuracy: 0.8371
# Epoch 6/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4625 - accuracy: 0.8403 - val_loss: 0.4637 - val_accuracy: 0.8426
# Epoch 7/20
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4411 - accuracy: 0.8496 - val_loss: 0.4444 - val_accuracy: 0.8489
# Epoch 8/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.4294 - accuracy: 0.8523 - val_loss: 0.4383 - val_accuracy: 0.8509
# Epoch 9/20
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4143 - accuracy: 0.8575 - val_loss: 0.4227 - val_accuracy: 0.8564
# Epoch 10/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4016 - accuracy: 0.8621 - val_loss: 0.4167 - val_accuracy: 0.8578
# Epoch 11/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3919 - accuracy: 0.8665 - val_loss: 0.4084 - val_accuracy: 0.8578
# Epoch 12/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3847 - accuracy: 0.8674 - val_loss: 0.4007 - val_accuracy: 0.8607
# Epoch 13/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3761 - accuracy: 0.8698 - val_loss: 0.4099 - val_accuracy: 0.8577
# Epoch 14/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3707 - accuracy: 0.8711 - val_loss: 0.3936 - val_accuracy: 0.8632
# Epoch 15/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.3617 - accuracy: 0.8751 - val_loss: 0.3844 - val_accuracy: 0.8666
# Epoch 16/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3540 - accuracy: 0.8781 - val_loss: 0.3831 - val_accuracy: 0.8649
# Epoch 17/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.3478 - accuracy: 0.8795 - val_loss: 0.3774 - val_accuracy: 0.8683
# Epoch 18/20
# 21/21 [==============================] - 1s 33ms/step - loss: 0.3438 - accuracy: 0.8812 - val_loss: 0.3746 - val_accuracy: 0.8681
# Epoch 19/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3391 - accuracy: 0.8817 - val_loss: 0.3726 - val_accuracy: 0.8691
# Epoch 20/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3334 - accuracy: 0.8841 - val_loss: 0.3663 - val_accuracy: 0.8703

# %%
# loss 값을 plot 해보겠습니다. 
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph without batch normalization') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다. 
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1)
plt.title('Accuracy graph without batch normalization') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
# Q. 두 개의 dense layer 사이에 batch normalization layer를 추가하는 코드입니다.

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    # 여기에 batch normalization layer를 추가해보았습니다. 나머지 layer는 위의 실습과 같습니다.
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(X_train, y_train, epochs=20, batch_size=2048, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 21/21 [==============================] - 5s 77ms/step - loss: 0.8431 - accuracy: 0.7188 - val_loss: 0.9511 - val_accuracy: 0.7235
# Epoch 2/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.4654 - accuracy: 0.8379 - val_loss: 0.8158 - val_accuracy: 0.7647
# Epoch 3/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.4128 - accuracy: 0.8556 - val_loss: 0.7103 - val_accuracy: 0.8085
# Epoch 4/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.3773 - accuracy: 0.8683 - val_loss: 0.6529 - val_accuracy: 0.8191
# Epoch 5/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.3526 - accuracy: 0.8774 - val_loss: 0.6063 - val_accuracy: 0.8279
# Epoch 6/20
# 21/21 [==============================] - 1s 66ms/step - loss: 0.3319 - accuracy: 0.8823 - val_loss: 0.5721 - val_accuracy: 0.8442
# Epoch 7/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.3144 - accuracy: 0.8899 - val_loss: 0.5296 - val_accuracy: 0.8500
# Epoch 8/20
# 21/21 [==============================] - 1s 65ms/step - loss: 0.3000 - accuracy: 0.8934 - val_loss: 0.5050 - val_accuracy: 0.8546
# Epoch 9/20
# 21/21 [==============================] - 1s 65ms/step - loss: 0.2864 - accuracy: 0.8990 - val_loss: 0.4742 - val_accuracy: 0.8601
# Epoch 10/20
# 21/21 [==============================] - 1s 65ms/step - loss: 0.2718 - accuracy: 0.9040 - val_loss: 0.4596 - val_accuracy: 0.8618
# Epoch 11/20
# 21/21 [==============================] - 1s 63ms/step - loss: 0.2599 - accuracy: 0.9086 - val_loss: 0.4339 - val_accuracy: 0.8657
# Epoch 12/20
# 21/21 [==============================] - 1s 65ms/step - loss: 0.2472 - accuracy: 0.9147 - val_loss: 0.4185 - val_accuracy: 0.8692
# Epoch 13/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.2435 - accuracy: 0.9156 - val_loss: 0.3939 - val_accuracy: 0.8724
# Epoch 14/20
# 21/21 [==============================] - 1s 63ms/step - loss: 0.2370 - accuracy: 0.9175 - val_loss: 0.4000 - val_accuracy: 0.8666
# Epoch 15/20
# 21/21 [==============================] - 1s 64ms/step - loss: 0.2266 - accuracy: 0.9215 - val_loss: 0.3711 - val_accuracy: 0.8710
# Epoch 16/20
# 21/21 [==============================] - 1s 67ms/step - loss: 0.2143 - accuracy: 0.9251 - val_loss: 0.3590 - val_accuracy: 0.8791
# Epoch 17/20
# 21/21 [==============================] - 1s 70ms/step - loss: 0.2084 - accuracy: 0.9276 - val_loss: 0.3591 - val_accuracy: 0.8764
# Epoch 18/20
# 21/21 [==============================] - 1s 73ms/step - loss: 0.1976 - accuracy: 0.9322 - val_loss: 0.3394 - val_accuracy: 0.8819
# Epoch 19/20
# 21/21 [==============================] - 1s 62ms/step - loss: 0.1903 - accuracy: 0.9350 - val_loss: 0.3430 - val_accuracy: 0.8762
# Epoch 20/20
# 21/21 [==============================] - 1s 69ms/step - loss: 0.1859 - accuracy: 0.9357 - val_loss: 0.3483 - val_accuracy: 0.8763

# %%
# loss 값을 plot 해보겠습니다. 
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph with batch normalization') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다. 
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accurcy graph with batch normalization') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# 기존의 fully connected layer도 낮지 않은 결과를 가져오지만, batch normalization을 추가하니 좀 더 빠르게 정확도 상승이 있음을 확인할 수 있습니다. 또한 loss 함수의 감소도 더 빨라짐을 확인할 수 있었습니다. 즉 batch normalization으로 인해 데이터 분포가 정규화되면서 좀 더 고른 분포를 가지기도 하며, 모델과 함께 학습되는 γ, β 파라미터로 데이터 분포를 적절하게 변환함으로써 보다 안정적인 학습이 가능해집니다.

# %% [markdown]
# ### 종합퀴즈
# ---
# Q. L1 regularization과 L2 regularization의 공통점과 차이점은 무엇이었나요?
#
# [공통점]
# 두 방법 모두 Lp norm 개념을 사용하고 있고, 오버피팅이 발생하지 않도록 모델에 제약 조건을 걸어줍니다.
#
# [차이점]
# L1 regularization(Lasso)은 L1 norm을 사용하며, 일부 coefficient 값을 0으로 보내기 때문에 차원 축소와 비슷한 역할을 합니다.
# L2 regularization(Ridge)은 L2 norm을 사용하며, 계수를 0으로 보내지는 않지만 제곱 항이 있기 때문에 L1 regularization보다는 수렴 속도가 빠르다는 장점이 있습니다.
